# %% [markdown]
# ###Question 1 -
# Implement 3 different CNN architectures with a comparison table for the MNSIT  dataset using the Tensorflow library.
# ####Note -
# 1. The model parameters for each architecture should not be more than 8000
# parameters
# 2. Code comments should be given for proper code understanding.
# 3. The minimum accuracy for each accuracy should be at least 96%
#
# ###  Importing necessary libraries ,mnist data set,keras and its layers ,models as squential,optimizer,performance metrics as accuracy

# %%
import keras
from keras.datasets import mnist
from keras.layers import Conv2D,MaxPooling2D
from keras.layers import Dense,Flatten
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# %%
# Loading the dataset and perform splitting
(x_train,y_train),(x_test,y_test)=mnist.load_data()

### print the shape
print(x_train.shape)
print(x_test.shape)
print(y_train.shape[0])

# Peforming reshaping operation to conver image  to 1d array(28*28)
x_train=x_train.reshape(x_train.shape[0],28,28,1)
x_test=x_test.reshape(x_test.shape[0],28,28,1)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# 60000

# %%
# Normalization Each image has Intensity from 0 to 255
x_train = x_train / 255
x_test = x_test / 255

# 
# One Hot Encoding is required  for categorical feature since output to be predicted is handwritten image ,
### we have multiclass results(0–9: 10 output)
y_train =keras.utils.to_categorical(y_train,10)
y_test = keras.utils.to_categorical(y_test,10)

# %%
model1 = Sequential([
    Conv2D(6, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(10, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(30, activation='relu'),
    Dense(10, activation='softmax')
])
print("--------- Model1 Summary----------")
print(model1.summary())
print('!!Starting  Trainging  on Model 1!')
# Compile and train the first model
model1.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model1.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))
print('Model 1 trained successfully!')
# Out:
# --------- Model1 Summary----------
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_2 (Conv2D)           (None, 26, 26, 6)         60
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 6)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 10)        550
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 10)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 250)               0
#
#  dense_2 (Dense)             (None, 30)                7530
#
#  dense_3 (Dense)             (None, 10)                310
#
# ...
# Total params: 8,450
# Trainable params: 8,450
# Non-trainable params: 0
# _________________________________________________________________
# None
# !!Starting  Trainging  on Model 1!
# Epoch 1/10
# 1875/1875 [==============================] - 34s 17ms/step - loss: 0.2841 - accuracy: 0.9132 - val_loss: 0.1087 - val_accuracy: 0.9666
# Epoch 2/10
# ...

# %%
model2 = Sequential([
    Conv2D(8, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(12, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(15, activation='relu'),
    Dense(10, activation='softmax')
])

print("--------- Model2 Summary---------")
print(model2.summary())
print('!!Starting  Trainging  on Model 2!')
# Compile and train the first model
model2.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model2.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))
print('Model 2 trained successfully!')
# Out:
# --------- Model2 Summary---------
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 26, 26, 8)         80
#
#  max_pooling2d_4 (MaxPooling  (None, 13, 13, 8)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 12)        876
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 5, 12)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 300)               0
#
#  dense_4 (Dense)             (None, 15)                4515
#
#  dense_5 (Dense)             (None, 10)                160
#
# ...
# Total params: 5,631
# Trainable params: 5,631
# Non-trainable params: 0
# _________________________________________________________________
# None
# !!Starting  Trainging  on Model 2!
# Epoch 1/10
# 1875/1875 [==============================] - 34s 17ms/step - loss: 0.3187 - accuracy: 0.9031 - val_loss: 0.1098 - val_accuracy: 0.9659
# Epoch 2/10
# ...

# %%
model3 = Sequential([
    Conv2D(6, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(14, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(20,activation='relu'),
    Dense(20, activation='relu'),
    Dense(10, activation='softmax')
])

print("--------- Model3 Summary---------")
print(model3.summary())
print('!!Starting  Trainging  on Model 3!')
# Compile and train the first model
model3.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model3.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))
print('Model 3 trained successfully!')
# Out:
# --------- Model3 Summary---------
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 26, 26, 6)         60
#
#  max_pooling2d_6 (MaxPooling  (None, 13, 13, 6)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 14)        770
#
#  max_pooling2d_7 (MaxPooling  (None, 5, 5, 14)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 350)               0
#
#  dense_6 (Dense)             (None, 20)                7020
#
#  dense_7 (Dense)             (None, 20)                420
#
#  dense_8 (Dense)             (None, 10)                210
#
# ...
# Total params: 8,480
# Trainable params: 8,480
# Non-trainable params: 0
# _________________________________________________________________
# None
# !!Starting  Trainging  on Model 3!
# Epoch 1/10
# ...

# %%
# Evaluate the models on the test set
_, accuracy1 = model1.evaluate(x_test, y_test, verbose=0)
_, accuracy2 = model2.evaluate(x_test, y_test, verbose=0)
_, accuracy3 = model3.evaluate(x_test, y_test, verbose=0)

# Create a comparison table
print ("Comparision Table of Various implemented CNN Architectures")
print(" CNN Architectures \t\t Accuracy")
print("-------------------------------------------------")
print("Model 1\t\t\t{:.2f}%".format(accuracy1 * 100))
print("Model 2\t\t\t{:.2f}%".format(accuracy2 * 100))
print("Model 3\t\t\t{:.2f}%".format(accuracy3 * 100))
# Out:
# Comparision Table of Various implemented CNN Architectures
#  CNN Architectures 		 Accuracy
# -------------------------------------------------
# Model 1			98.42%
# Model 2			98.46%
# Model 3			98.57%
